# %% [markdown]
# # 🌳 Estrategia S6: Per-Client F1-Score
#
# **Federated Proactive Forest - Estrategia de Agregación S6**
#
# Este notebook demuestra el flujo completo de entrenamiento e inferencia utilizando la estrategia **S6: Per-Client F1-Score**, que ranking los árboles dentro de cada cliente independientemente por F1-Score macro e incorpora mediante round-robin con Progressive Forest early stopping.
#
# ## 📋 Contenido
# 1. Configuración inicial
# 2. Carga y preparación del dataset
# 3. Configuración del entrenamiento federado
# 4. Entrenamiento de bosques locales
# 5. Agregación con Ranking Per-Cliente por F1-Score
# 6. Evaluación del modelo global
# 7. Predicción híbrida por cliente

# %% [markdown]
# ## 1️⃣ Configuración Inicial
#
# Importamos las librerías necesarias y configuramos el entorno.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split

# Configurar estilo de gráficos
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

print("✅ Librerías cargadas correctamente")
# Out:
# ✅ Librerías cargadas correctamente

# %% [markdown]
# ## 2️⃣ Carga y Preparación del Dataset
#
# Cargamos el dataset `students_dropout.csv` y realizamos la preparación básica.

# %%
# Cargar dataset
df = pd.read_csv('../../../data/students_dropout.csv', sep=';')

print(f"📊 Dataset cargado: {df.shape[0]} muestras, {df.shape[1]} características")
print(f"\nColumnas: {list(df.columns)}")
print(f"\nDistribución de la variable objetivo:")
print(df['Target'].value_counts())
# Out:
# 📊 Dataset cargado: 4424 muestras, 37 características
#
# Columnas: ['Marital status', 'Application mode', 'Application order', 'Course', 'Daytime/evening attendance', 'Previous qualification', 'Previous qualification (grade)', 'Nacionality', "Mother's qualification", "Father's qualification", "Mother's occupation", "Father's occupation", 'Admission grade', 'Displaced', 'Educational special needs', 'Debtor', 'Tuition fees up to date', 'Gender', 'Scholarship holder', 'Age at enrollment', 'International', 'Curricular units 1st sem (credited)', 'Curricular units 1st sem (enrolled)', 'Curricular units 1st sem (evaluations)', 'Curricular units 1st sem (approved)', 'Curricular units 1st sem (grade)', 'Curricular units 1st sem (without evaluations)', 'Curricular units 2nd sem (credited)', 'Curricular units 2nd sem (enrolled)', 'Curricular units 2nd sem (evaluations)', 'Curricular units 2nd sem (approved)', 'Curricular units 2nd sem (grade)', 'Curricular units 2nd sem (without evaluations)', 'Unemployment rate', 'Inflation rate', 'GDP', 'Target']
#
# Distribución de la variable objetivo:
# Target
# Graduate    2209
# Dropout     1421
# Enrolled     794
# Name: count, dtype: int64

# %%
# Preparar características y variable objetivo
target_column = 'Target'
feature_columns = [col for col in df.columns if col != target_column]

# Separar features y target
X = df[feature_columns].values.astype(np.float64)
y = df[target_column].values

# Codificar labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)
class_names = list(le.classes_)

print(f"\n✅ Features: {X.shape}")
print(f"✅ Labels codificados: {np.unique(y_encoded)}")
print(f"✅ Clases: {class_names}")
# Out:
# ✅ Features: (4424, 36)
# ✅ Labels codificados: [0 1 2]
# ✅ Clases: ['Dropout', 'Enrolled', 'Graduate']

# %%
# Dividir en train/test (80/20)
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)

# Escalar features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print(f"\n📈 Train: {X_train_scaled.shape[0]} muestras")
print(f"📉 Test: {X_test_scaled.shape[0]} muestras")
# Out:
# 📈 Train: 3539 muestras
# 📉 Test: 885 muestras

# %% [markdown]
# ## 3️⃣ Configuración del Entrenamiento Federado
#
# Configuramos el orquestador FL con los hiperparámetros por defecto y la estrategia S6.

# %%
# Importar componentes del framework
import sys
sys.path.append('../../../')

from src.application.fl_orchestrator import FLEXOrchestrator, DatasetSplit
from src.domain.aggregation.aggregation_factory import AggregationFactory

print("✅ Componentes importados correctamente")
# Out:
# ✅ Componentes importados correctamente

# %%
# Configurar entrenamiento federado
config = {
    'n_clients': 5,              # Número de clientes
    'distribution': 'iid',        # Distribución IID
    'strategy': 'S6',             # Estrategia S6: Per-Client F1-Score
    'n_estimators': 100,          # Número de árboles por cliente
    'alpha_pf': 0.1,              # Parámetro Proactive Forest
    'verbose': False
}

# Crear DatasetSplit
dataset_split = DatasetSplit(
    X_train=X_train_scaled,
    X_test=X_test_scaled,
    y_train=y_train,
    y_test=y_test,
    feature_names=feature_columns,
    class_names=class_names,
    dataset_name='Students Dropout'
)

# Crear orquestador
orchestrator = FLEXOrchestrator.from_config(config)

print("✅ Configuración completada")
print(f"   - Clientes: {config['n_clients']}")
print(f"   - Distribución: {config['distribution']}")
print(f"   - Estrategia: {config['strategy']} (Per-Client F1-Score)")
print(f"   - Árboles por cliente: {config['n_estimators']}")
# Out:
# ✅ Configuración completada
#    - Clientes: 5
#    - Distribución: iid
#    - Estrategia: S6 (Per-Client F1-Score)
#    - Árboles por cliente: 100

# %%
# Configurar federación
orchestrator.setup_federation(dataset_split, seed=42)

print("✅ Federación configurada")
print(f"   - Particiones de clientes: {list(orchestrator.client_partitions.keys())}")
# Out:
# ✅ Federación configurada
#    - Particiones de clientes: ['client_0', 'client_1', 'client_2', 'client_3', 'client_4']

# %% [markdown]
# ## 4️⃣ Entrenamiento de Bosques Locales
#
# Cada cliente entrena su bosque local Proactive Forest con sus propios datos.

# %%
# Ejecutar ronda federada completa
results = orchestrator.run_federated_round()

print("\n✅ Ronda federada completada")
# Out:
# DEBUG _train_local_forests client_0: y_pred_test sample=['Graduate' 'Graduate' 'Dropout' 'Graduate' 'Graduate'] type=<class 'numpy.str_'>
# DEBUG _train_local_forests client_0: y_test sample=[2 2 1 2 2] type=<class 'numpy.int32'>
# DEBUG _train_local_forests client_1: y_pred_test sample=['Graduate' 'Graduate' 'Dropout' 'Graduate' 'Graduate'] type=<class 'numpy.str_'>
# DEBUG _train_local_forests client_1: y_test sample=[2 2 1 2 2] type=<class 'numpy.int32'>
# DEBUG _train_local_forests client_2: y_pred_test sample=['Graduate' 'Graduate' 'Dropout' 'Graduate' 'Graduate'] type=<class 'numpy.str_'>
# DEBUG _train_local_forests client_2: y_test sample=[2 2 1 2 2] type=<class 'numpy.int32'>
# DEBUG _train_local_forests client_3: y_pred_test sample=['Graduate' 'Graduate' 'Dropout' 'Graduate' 'Graduate'] type=<class 'numpy.str_'>
# DEBUG _train_local_forests client_3: y_test sample=[2 2 1 2 2] type=<class 'numpy.int32'>
# DEBUG _train_local_forests client_4: y_pred_test sample=['Graduate' 'Graduate' 'Dropout' 'Graduate' 'Graduate'] type=<class 'numpy.str_'>
# DEBUG _train_local_forests client_4: y_test sample=[2 2 1 2 2] type=<class 'numpy.int32'>
#
# ============================================================
# 🌳 ÁRBOLES ENTRENADOS POR CLIENTE
# ============================================================
#   client_0: 16 árboles entrenados
#   client_1: 24 árboles entrenados
#   client_2: 100 árboles entrenados
#   client_3: 24 árboles entrenados
#   client_4: 56 árboles entrenados
#   TOTAL: 220 árboles
#
# ============================================================
# 📊 ÁRBOLES SELECCIONADOS (Estrategia: S6)
# ============================================================
#   client_0: 5/16 árboles seleccionados
#   client_1: 5/24 árboles seleccionados
#   client_2: 5/100 árboles seleccionados
#   client_3: 5/24 árboles seleccionados
#   client_4: 4/56 árboles seleccionados
#
# ============================================================
# 🌲 BOSQUE GLOBAL
# ============================================================
#   Tamaño final: 24 árboles
#
# ============================================================
# 📈 TAMAÑO FINAL POR CLIENTE (sin duplicados)
# ============================================================
#   client_0: 16 locales + 19 globales externos (5 propios excluidos) = 35 árboles
#   client_1: 24 locales + 19 globales externos (5 propios excluidos) = 43 árboles
#   client_2: 100 locales + 19 globales externos (5 propios excluidos) = 119 árboles
#   client_3: 24 locales + 19 globales externos (5 propios excluidos) = 43 árboles
#   client_4: 56 locales + 20 globales externos (4 propios excluidos) = 76 árboles
# ============================================================
#
# [DEBUG] global_predictions type: <class 'numpy.int32'>, shape: (885,)
# [DEBUG] y_test type: <class 'numpy.int32'>, shape: (885,)
# c:\Users\Adrián Rodríguez\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:226: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   score = y_true == y_pred
# [ERROR] evaluate_local_pf_model_at_clients: Mix of label input types (string and number)
# c:\Users\Adrián Rodríguez\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:226: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   score = y_true == y_pred
# [ERROR] evaluate_local_pf_model_at_clients: Mix of label input types (string and number)
# c:\Users\Adrián Rodríguez\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:226: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   score = y_true == y_pred
# [ERROR] evaluate_local_pf_model_at_clients: Mix of label input types (string and number)
# c:\Users\Adrián Rodríguez\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:226: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   score = y_true == y_pred
# [ERROR] evaluate_local_pf_model_at_clients: Mix of label input types (string and number)
# c:\Users\Adrián Rodríguez\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:226: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   score = y_true == y_pred
# [ERROR] evaluate_local_pf_model_at_clients: Mix of label input types (string and number)
#
# ✅ Ronda federada completada

# %% [markdown]
# ## 5️⃣ Agregación con Ranking Per-Cliente por F1-Score
#
# La estrategia S6 ranking los árboles dentro de cada cliente independientemente por F1-Score macro, luego incorpora mediante round-robin (turnos rotativos) con Progressive Forest early stopping.

# %%
print("=" * 60)
print("📊 RESULTADOS DE AGREGACIÓN - S6 PER-CLIENT F1-SCORE")
print("=" * 60)

print(f"\n🌳 Árboles en el bosque global: {results.n_trees_global}")
print(f"\n📈 Árboles seleccionados por cliente:")
for client_id, indices in results.selected_ids.items():
    print(f"   {client_id}: {len(indices)} árboles seleccionados")
# Out:
# ============================================================
# 📊 RESULTADOS DE AGREGACIÓN - S6 PER-CLIENT F1-SCORE
# ============================================================
#
# 🌳 Árboles en el bosque global: 24
#
# 📈 Árboles seleccionados por cliente:
#    client_0: 5 árboles seleccionados
#    client_1: 5 árboles seleccionados
#    client_2: 5 árboles seleccionados
#    client_3: 5 árboles seleccionados
#    client_4: 4 árboles seleccionados

# %%
# Visualizar contribución de árboles por cliente
client_contributions = {cid: len(indices) for cid, indices in results.selected_ids.items()}

plt.figure(figsize=(10, 5))
bars = plt.bar(client_contributions.keys(), client_contributions.values(), color='mediumorchid')
plt.xlabel('Cliente', fontsize=12)
plt.ylabel('Número de Árboles', fontsize=12)
plt.title('Contribución de Árboles por Cliente - Estrategia S6 (Per-Client F1-Score)', fontsize=14)
plt.xticks(rotation=45)

# Añadir etiquetas de valor
for bar, val in zip(bars, client_contributions.values()):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 1, 
             str(val), ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# %%
# Mostrar top 3 árboles por F1-Score para cada cliente
if results.all_tree_entries and len(results.all_tree_entries) > 0:
    print("\n" + "=" * 60)
    print("🏆 TOP 3 ÁRBOLES POR F1-SCORE POR CLIENTE")
    print("=" * 60)
    
    # Agrupar por cliente
    from collections import defaultdict
    client_entries = defaultdict(list)
    for entry in results.all_tree_entries:
        client_entries[entry.client_id].append(entry)
    
    for client_id in sorted(client_entries.keys()):
        entries = client_entries[client_id]
        sorted_entries = sorted(entries, key=lambda e: e.macro_f1, reverse=True)
        print(f"\n{client_id}:")
        print(f"  {'Rank':<6}{'Accuracy':<12}{'F1-Score':<12}{'PCD':<10}")
        print(f"  {'-'*40}")
        for i, entry in enumerate(sorted_entries[:3], 1):
            print(f"  {i:<6}{entry.accuracy:<12.4f}{entry.macro_f1:<12.4f}{entry.pcd:<10.4f}")
# Out:
# ============================================================
# 🏆 TOP 3 ÁRBOLES POR F1-SCORE POR CLIENTE
# ============================================================
#
# client_0:
#   Rank  Accuracy    F1-Score    PCD
#   ----------------------------------------
#   1     0.6960      0.6064      0.7390
#   2     0.6960      0.6064      0.7390
#   3     0.6960      0.6064      0.7390
#
# client_1:
#   Rank  Accuracy    F1-Score    PCD
#   ----------------------------------------
#   1     0.7480      0.6285      0.6294
#   2     0.7480      0.6285      0.6294
#   3     0.7480      0.6285      0.6294
#
# client_2:
#   Rank  Accuracy    F1-Score    PCD
#   ----------------------------------------
#   1     0.7435      0.6676      0.7458
#   2     0.7435      0.6676      0.7458
#   3     0.7435      0.6676      0.7458
#
# client_3:
#   Rank  Accuracy    F1-Score    PCD
#   ----------------------------------------
#   1     0.7107      0.6222      0.6644
#   2     0.7107      0.6222      0.6644
#   3     0.7107      0.6222      0.6644
#
# client_4:
#   Rank  Accuracy    F1-Score    PCD
#   ----------------------------------------
#   1     0.7390      0.6178      0.7367
#   2     0.7390      0.6178      0.7367
#   3     0.7390      0.6178      0.7367

# %% [markdown]
# ## 6️⃣ Evaluación del Modelo Global
#
# Evaluamos el rendimiento del bosque global en el conjunto de test.

# %%
print("=" * 60)
print("📊 MÉTRICAS DEL MODELO GLOBAL")
print("=" * 60)

print(f"\n🎯 Precisión (Accuracy): {results.global_accuracy:.4f}")
print(f"📊 F1-Score Macro: {results.global_macro_f1:.4f}")

# Obtener predicciones del reporte global
global_report = results.global_report
print(f"\n📈 Matriz de confusión:")
print(global_report.confusion_matrix)
# Out:
# ============================================================
# 📊 MÉTRICAS DEL MODELO GLOBAL
# ============================================================
#
# 🎯 Precisión (Accuracy): 0.7333
# 📊 F1-Score Macro: 0.6259
#
# 📈 Matriz de confusión:
# [[205  32  47]
#  [ 54  37  68]
#  [ 14  21 407]]

# %%
# Visualizar matriz de confusión
plt.figure(figsize=(8, 6))
cm = global_report.confusion_matrix
sns.heatmap(cm, annot=True, fmt='d', cmap='PuOr', 
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicción', fontsize=12)
plt.ylabel('Real', fontsize=12)
plt.title('Matriz de Confusión - Modelo Global (S6)', fontsize=14)
plt.tight_layout()
plt.show()

# %%
# Reporte de clasificación detallado

print("\n" + "=" * 60)
print("📋 REPORTE DE CLASIFICACIÓN")
print("=" * 60)
print(f"Accuracy: {global_report.accuracy:.4f}")
print(f"F1-Score (Macro): {global_report.macro_f1:.4f}")
print(f"Precisión (Macro): {global_report.macro_precision:.4f}")
print(f"Recall (Macro): {global_report.macro_recall:.4f}")
print(f"\nF1-Score por clase:")
for cls, f1 in global_report.per_class_f1.items():
    print(f"   {cls}: {f1:.4f}")
print(f"\nPrecisión por clase:")
for cls, prec in global_report.per_class_prec.items():
    print(f"   {cls}: {prec:.4f}")
print(f"\nRecall por clase:")
for cls, rec in global_report.per_class_recall.items():
    print(f"   {cls}: {rec:.4f}")
# Out:
# ============================================================
# 📋 REPORTE DE CLASIFICACIÓN
# ============================================================
# Accuracy: 0.7333
# F1-Score (Macro): 0.6259
# Precisión (Macro): 0.6472
# Recall (Macro): 0.6251
#
# F1-Score por clase:
#    Dropout: 0.7361
#    Enrolled: 0.2972
#    Graduate: 0.8444
#
# Precisión por clase:
#    Dropout: 0.7509
#    Enrolled: 0.4111
#    Graduate: 0.7797
#
# Recall por clase:
#    Dropout: 0.7218
#    Enrolled: 0.2327
#    Graduate: 0.9208

# %% [markdown]
# ## 7️⃣ Predicción Híbrida por Cliente
#
# Cada cliente utiliza una combinación de su bosque local y el bosque global (excluyendo sus propios árboles) para realizar predicciones.

# %%
print("=" * 60)
print("📊 MÉTRICAS DE PREDICCIÓN HÍBRIDA POR CLIENTE")
print("=" * 60)

for client_id in results.client_ids:
    print(f"\n{client_id}:")
    print(f"   - Accuracy local: {results.client_accuracies[client_id]:.4f}")
    print(f"   - F1-Score local: {results.client_f1_scores[client_id]:.4f}")
    print(f"   - Tamaño del bosque híbrido: {results.client_hybrid_forest_sizes[client_id]} árboles")
# Out:
# ============================================================
# 📊 MÉTRICAS DE PREDICCIÓN HÍBRIDA POR CLIENTE
# ============================================================
#
# client_0:
#    - Accuracy local: 0.6960
#    - F1-Score local: 0.6064
#    - Tamaño del bosque híbrido: 35 árboles
#
# client_1:
#    - Accuracy local: 0.7480
#    - F1-Score local: 0.6285
#    - Tamaño del bosque híbrido: 43 árboles
#
# client_2:
#    - Accuracy local: 0.7435
#    - F1-Score local: 0.6676
#    - Tamaño del bosque híbrido: 119 árboles
#
# client_3:
#    - Accuracy local: 0.7107
#    - F1-Score local: 0.6222
#    - Tamaño del bosque híbrido: 43 árboles
#
# client_4:
#    - Accuracy local: 0.7390
#    - F1-Score local: 0.6178
#    - Tamaño del bosque híbrido: 76 árboles

# %%
# Calcular métricas de predicción híbrida por cliente
print("\n" + "=" * 60)
print("📈 PRECISIÓN POR CLIENTE (Predicción Híbrida)")
print("=" * 60)

client_accuracies = {}
client_f1_scores = {}

for client_id, hybrid_preds in results.client_hybrid_predictions.items():
    acc = accuracy_score(results.y_test, hybrid_preds)
    f1 = f1_score(results.y_test, hybrid_preds, average='macro', zero_division=0)
    client_accuracies[client_id] = acc
    client_f1_scores[client_id] = f1
    print(f"{client_id}: Accuracy = {acc:.4f}, F1-Score = {f1:.4f}")
# Out:
# ============================================================
# 📈 PRECISIÓN POR CLIENTE (Predicción Híbrida)
# ============================================================
# client_0: Accuracy = 0.7492, F1-Score = 0.6499
# client_1: Accuracy = 0.7412, F1-Score = 0.6335
# client_2: Accuracy = 0.7446, F1-Score = 0.6459
# client_3: Accuracy = 0.7322, F1-Score = 0.6210
# client_4: Accuracy = 0.7469, F1-Score = 0.6374

# %%
# Visualizar métricas por cliente
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Accuracy por cliente
ax1 = axes[0]
bars1 = ax1.bar(client_accuracies.keys(), client_accuracies.values(), color='coral')
ax1.axhline(y=results.global_accuracy, color='red', linestyle='--', linewidth=2, 
            label=f'Global: {results.global_accuracy:.4f}')
ax1.set_xlabel('Cliente', fontsize=12)
ax1.set_ylabel('Accuracy', fontsize=12)
ax1.set_title('Accuracy por Cliente', fontsize=14)
ax1.legend()
ax1.set_ylim(0, 1)

# F1-Score por cliente
ax2 = axes[1]
bars2 = ax2.bar(client_f1_scores.keys(), client_f1_scores.values(), color='steelblue')
ax2.axhline(y=results.global_macro_f1, color='darkblue', linestyle='--', linewidth=2,
            label=f'Global: {results.global_macro_f1:.4f}')
ax2.set_xlabel('Cliente', fontsize=12)
ax2.set_ylabel('F1-Score (Macro)', fontsize=12)
ax2.set_title('F1-Score por Cliente', fontsize=14)
ax2.legend()
ax2.set_ylim(0, 1)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📊 Resumen Final
#
# Comparativa completa de todos los resultados.

# %%
# Crear resumen completo
summary_df = pd.DataFrame({
    'Cliente': list(client_accuracies.keys()),
    'Accuracy Local': [results.client_accuracies[cid] for cid in client_accuracies.keys()],
    'F1 Local': [results.client_f1_scores[cid] for cid in client_f1_scores.keys()],
    'Accuracy Híbrido': list(client_accuracies.values()),
    'F1 Híbrido': list(client_f1_scores.values()),
    'Tamaño Bosque': [results.client_hybrid_forest_sizes[cid] for cid in client_accuracies.keys()]
})

# Añadir fila global
summary_df.loc[len(summary_df)] = ['GLOBAL', results.global_accuracy, results.global_macro_f1, 
                                    results.global_accuracy, results.global_macro_f1, 
                                    results.n_trees_global]

print("\n" + "=" * 80)
print("📋 RESUMEN COMPLETO - ESTRATEGIA S6 PER-CLIENT F1-SCORE")
print("=" * 80)
print(summary_df.to_string(index=False))
# Out:
# ================================================================================
# 📋 RESUMEN COMPLETO - ESTRATEGIA S6 PER-CLIENT F1-SCORE
# ================================================================================
#  Cliente  Accuracy Local  F1 Local  Accuracy Híbrido  F1 Híbrido  Tamaño Bosque
# client_0        0.696045  0.606419          0.749153    0.649876             35
# client_1        0.748023  0.628503          0.741243    0.633543             43
# client_2        0.743503  0.667620          0.744633    0.645926            119
# client_3        0.710734  0.622217          0.732203    0.621045             43
# client_4        0.738983  0.617826          0.746893    0.637383             76
#   GLOBAL        0.733333  0.625891          0.733333    0.625891             24

# %%
# Visualización comparativa final
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1. Comparativa Accuracy Local vs Híbrido
ax1 = axes[0, 0]
x = np.arange(len(client_accuracies))
width = 0.35
local_acc = [results.client_accuracies[cid] for cid in client_accuracies.keys()]
hybrid_acc = list(client_accuracies.values())
ax1.bar(x - width/2, local_acc, width, label='Local', color='lightcoral')
ax1.bar(x + width/2, hybrid_acc, width, label='Híbrido', color='darkred')
ax1.set_ylabel('Accuracy', fontsize=12)
ax1.set_title('Accuracy: Local vs Híbrido', fontsize=14)
ax1.set_xticks(x)
ax1.set_xticklabels(client_accuracies.keys())
ax1.legend()
ax1.set_ylim(0, 1)

# 2. Comparativa F1-Score Local vs Híbrido
ax2 = axes[0, 1]
local_f1 = [results.client_f1_scores[cid] for cid in client_f1_scores.keys()]
hybrid_f1 = list(client_f1_scores.values())
ax2.bar(x - width/2, local_f1, width, label='Local', color='lightblue')
ax2.bar(x + width/2, hybrid_f1, width, label='Híbrido', color='darkblue')
ax2.set_ylabel('F1-Score (Macro)', fontsize=12)
ax2.set_title('F1-Score: Local vs Híbrido', fontsize=14)
ax2.set_xticks(x)
ax2.set_xticklabels(client_accuracies.keys())
ax2.legend()
ax2.set_ylim(0, 1)

# 3. Distribución de árboles
ax3 = axes[1, 0]
colors = plt.cm.Set3(np.linspace(0, 1, len(results.selected_ids)))
ax3.pie([len(results.selected_ids[cid]) for cid in results.selected_ids.keys()],
        labels=results.selected_ids.keys(), autopct='%1.1f%%', colors=colors)
ax3.set_title('Distribución de Árboles por Cliente', fontsize=14)

# 4. Métricas globales
ax4 = axes[1, 1]
ax4.axis('off')
metrics_text = f"""
📊 MÉTRICAS GLOBALES

🎯 Accuracy: {results.global_accuracy:.4f}
📊 F1-Score: {results.global_macro_f1:.4f}
🌳 Total Árboles: {results.n_trees_global}
👥 Clientes: {len(results.client_ids)}

🔄 AGREGACIÓN ROUND-ROBIN
Ranking por F1-Score por cliente
"""
ax4.text(0.5, 0.5, metrics_text, fontsize=14, ha='center', va='center',
         bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Adrián Rodríguez\AppData\Local\Temp\ipykernel_2596\2666773046.py:56: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   plt.tight_layout()
# C:\Users\Adrián Rodríguez\AppData\Local\Temp\ipykernel_2596\2666773046.py:56: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from current font.
#   plt.tight_layout()
# C:\Users\Adrián Rodríguez\AppData\Local\Temp\ipykernel_2596\2666773046.py:56: UserWarning: Glyph 127795 (\N{DECIDUOUS TREE}) missing from current font.
#   plt.tight_layout()
# C:\Users\Adrián Rodríguez\AppData\Local\Temp\ipykernel_2596\2666773046.py:56: UserWarning: Glyph 128101 (\N{BUSTS IN SILHOUETTE}) missing from current font.
#   plt.tight_layout()
# C:\Users\Adrián Rodríguez\AppData\Local\Temp\ipykernel_2596\2666773046.py:56: UserWarning: Glyph 128260 (\N{ANTICLOCKWISE DOWNWARDS AND UPWARDS OPEN CIRCLE ARROWS}) missing from current font.
#   plt.tight_layout()
# C:\Users\Adrián Rodríguez\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Adrián Rodríguez\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Adrián Rodríguez\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 127795 (\N{DECIDUOUS TREE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Adrián Rodríguez\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128101 (\N{BUSTS IN SILHOUETTE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Adrián Rodríguez\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128260 (\N{ANTICLOCKWISE DOWNWARDS AND UPWARDS OPEN CIRCLE ARROWS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## ✅ Conclusiones
#
# La estrategia **S6: Per-Client F1-Score** utiliza un enfoque de ranking por cliente optimizando F1-Score:
#
# 1. **Ranking independiente por cliente**: Cada cliente ranking sus árboles por F1-Score macro
# 2. **Round-robin**: Los árboles se incorporan por turnos rotativos (un árbol de cada cliente por episodio)
# 3. **Early stopping**: Progressive Forest detiene la agregación cuando converge
# 4. **Equidad con optimización F1**: Todos los clientes contribuyen equitativamente, priorizando árboles con mejor balance precision/recall
#
# **Ventajas:**
# - Representación equitativa de todos los clientes
# - Ideal para datasets desbalanceados
# - Considera el rendimiento por clase dentro de cada cliente
# - Preserva la diversidad de contribuciones
#
# **Desventajas:**
# - Puede incluir árboles de menor calidad de clientes débiles
# - El F1-Score individual no garantiza buena contribución al ensemble
# - Requiere datos de validación para el early stopping
